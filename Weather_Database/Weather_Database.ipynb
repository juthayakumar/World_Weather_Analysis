# %%
import random
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitudes
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longtitudes to a list
coordinates = list(lat_lngs)

# Create a list to hold the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=534a6e63ad32dcc8dd8020073b9348e0

# %%
# create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | kahului
# Processing Record 2 of Set 16 | angoram
# Processing Record 3 of Set 16 | ukiah
# Processing Record 4 of Set 16 | san mateo ixtatan
# Processing Record 5 of Set 16 | longkou
# Processing Record 6 of Set 16 | bredasdorp
# Processing Record 7 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 16 | port hardy
# Processing Record 9 of Set 16 | yulara
# Processing Record 10 of Set 16 | port alfred
# Processing Record 11 of Set 16 | vaini
# Processing Record 12 of Set 16 | puerto ayora
# Processing Record 13 of Set 16 | hilo
# Processing Record 14 of Set 16 | tuktoyaktuk
# Processing Record 15 of Set 16 | broome
# Processing Record 16 of Set 16 | saint george
# Processing Record 17 of Set 16 | tual
# Processing Record 18 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 16 | butaritari
# Processing Record 20 of Set 16 | fairbanks
# Processing Record 21 of Set 16 | iqaluit
# Processing Record 22 of Set 16 | hobart
# Processing Record 23 of Set 16 | oussouye
# Processing Record 24 of Set 16 | parabel
# Processing Record 25 of Set 16 | rocha
# Processing Record 26 of Set 16 | san carlos
# Processing Record 27 of Set 16 | ushuaia
# Processing Record 28 of Set 16 | provideniya
# Processing Record 29 of Set 16 | barth
# Processing Record 30 of Set 16 | borger
# Processing Record 31 of Set 16 | punta arenas
# Processing Record 32 of Set 16 | astoria
# Processing Record 33 of Set 16 | bambous virieux
# Processing Record 34 of Set 16 | arraial do cabo
# Processing Record 35 of Set 16 | mae sot
# Processing Record 36 of Set 16 | dicabisagan
# Processing Record 37 of Set 16 | jalu
# Processing Record 38 of Set 16 | victoria
# Processing Record 39 of Set 16 | dudinka
# Processing Record 40 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 16 | usakos
# Processing Record 42 of Set 16 | dikson
# Processing Record 43 of Set 16 | narsaq
# Processing Record 44 of Set 16 | alofi
# Processing Record 45 of Set 16 | ostrovnoy
# Processing Record 46 of Set 16 | antofagasta
# Processing Record 47 of Set 16 | beloha
# Processing Record 48 of Set 16 | arkhangelsk
# Processing Record 49 of Set 16 | airai
# Processing Record 50 of Set 16 | moron
# Processing Record 1 of Set 17 | avarua
# Processing Record 2 of Set 17 | faya
# Processing Record 3 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 17 | atuona
# Processing Record 5 of Set 17 | isangel
# Processing Record 6 of Set 17 | kapaa
# Processing Record 7 of Set 17 | clyde river
# Processing Record 8 of Set 17 | esperance
# Processing Record 9 of Set 17 | rikitea
# Processing Record 10 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 17 | mirabad
# Processing Record 12 of Set 17 | tasiilaq
# Processing Record 13 of Set 17 | albany
# Processing Record 14 of Set 17 | new norfolk
# Processing Record 15 of Set 17 | sayyan
# Processing Record 16 of Set 17 | georgetown
# Processing Record 17 of Set 17 | longyearbyen
# Processing Record 18 of Set 17 | thompson
# Processing Record 19 of Set 17 | cockburn town
# Processing Record 20 of Set 17 | ribeira grande
# Processing Record 21 of Set 17 | yellowknife
# Processing Record 22 of Set 17 | hermanus
# Processing Record 23 of Set 17 | pemangkat
# Processing Record 24 of Set 17 | khatanga
# Processing Record 25 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 17 | qaanaaq
# Processing Record 27 of Set 17 | busselton
# Processing Record 28 of Set 17 | nikolskoye
# Processing Record 29 of Set 17 | ilheus
# Processing Record 30 of Set 17 | sol-iletsk
# Processing Record 31 of Set 17 | baghdad
# Processing Record 32 of Set 17 | portobelo
# Processing Record 33 of Set 17 | avola
# Processing Record 34 of Set 17 | coquimbo
# Processing Record 35 of Set 17 | mataura
# Processing Record 36 of Set 17 | kodiak
# Processing Record 37 of Set 17 | college
# Processing Record 38 of Set 17 | nanortalik
# Processing Record 39 of Set 17 | beringovskiy
# Processing Record 40 of Set 17 | ahipara
# Processing Record 41 of Set 17 | angoche
# Processing Record 42 of Set 17 | barrow
# Processing Record 43 of Set 17 | williamsburg
# Processing Record 44 of Set 17 | cape town
# Processing Record 45 of Set 17 | tvoroyri
# Processing Record 46 of Set 17 | lagoa
# Processing Record 47 of Set 17 | christchurch
# Processing Record 48 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 17 | port elizabeth
# Processing Record 50 of Set 17 | vestmannaeyjar
# Processing Record 1 of Set 18 | ponta do sol
# Processing Record 2 of Set 18 | constitucion
# Processing Record 3 of Set 18 | yar-sale
# Processing Record 4 of Set 18 | tura
# Processing Record 5 of Set 18 | nemuro
# Processing Record 6 of Set 18 | kuala terengganu
# Processing Record 7 of Set 18 | hun
# Processing Record 8 of Set 18 | castro
# Processing Record 9 of Set 18 | genhe
# Processing Record 10 of Set 18 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 18 | portland
# Processing Record 12 of Set 18 | yumen
# Processing Record 13 of Set 18 | partizan
# Processing Record 14 of Set 18 | bengkulu
# Processing Record 15 of Set 18 | nouakchott
# Processing Record 16 of Set 18 | novosineglazovskiy
# Processing Record 17 of Set 18 | mitilini
# City not found. Skipping...
# Processing Record 18 of Set 18 | quatre cocos
# Processing Record 19 of Set 18 | piacabucu
# Processing Record 20 of Set 18 | aklavik
# Processing Record 21 of Set 18 | krasavino
# Processing Record 22 of Set 18 | aksu
# Processing Record 23 of Set 18 | chuy
# Processing Record 24 of Set 18 | batagay
# Processing Record 25 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 18 | rundu
# Processing Record 27 of Set 18 | baruun-urt
# Processing Record 28 of Set 18 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 18 | goderich
# Processing Record 30 of Set 18 | sungaipenuh
# Processing Record 31 of Set 18 | geresk
# City not found. Skipping...
# Processing Record 32 of Set 18 | san cristobal
# Processing Record 33 of Set 18 | cabedelo
# Processing Record 34 of Set 18 | dubovskoye
# Processing Record 35 of Set 18 | salalah
# Processing Record 36 of Set 18 | tiksi
# Processing Record 37 of Set 18 | guerrero negro
# Processing Record 38 of Set 18 | shenzhen
# Processing Record 39 of Set 18 | makakilo city
# Processing Record 40 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 18 | amapa
# Processing Record 42 of Set 18 | alto araguaia
# Processing Record 43 of Set 18 | sault sainte marie
# Processing Record 44 of Set 18 | faanui
# Processing Record 45 of Set 18 | inhambane
# Processing Record 46 of Set 18 | chokurdakh
# Processing Record 47 of Set 18 | severo-kurilsk
# Processing Record 48 of Set 18 | batemans bay
# Processing Record 49 of Set 18 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 18 | jamestown
# Processing Record 1 of Set 19 | dunedin
# Processing Record 2 of Set 19 | bluff
# Processing Record 3 of Set 19 | grindavik
# Processing Record 4 of Set 19 | zhigansk
# Processing Record 5 of Set 19 | santo antonio do ica
# Processing Record 6 of Set 19 | sogdiondon
# City not found. Skipping...
# Processing Record 7 of Set 19 | mangalia
# Processing Record 8 of Set 19 | husavik
# Processing Record 9 of Set 19 | kavaratti
# Processing Record 10 of Set 19 | wakkanai
# Processing Record 11 of Set 19 | flin flon
# Processing Record 12 of Set 19 | maceio
# Processing Record 13 of Set 19 | maragogi
# Processing Record 14 of Set 19 | hays
# Processing Record 15 of Set 19 | kruisfontein
# Processing Record 16 of Set 19 | dogondoutchi
# Processing Record 17 of Set 19 | jian
# Processing Record 18 of Set 19 | high rock
# Processing Record 19 of Set 19 | billings
# Processing Record 20 of Set 19 | westerville
# Processing Record 21 of Set 19 | saskylakh
# Processing Record 22 of Set 19 | chapais
# Processing Record 23 of Set 19 | labuhan
# Processing Record 24 of Set 19 | sawtell
# Processing Record 25 of Set 19 | kanniyakumari
# Processing Record 26 of Set 19 | mar del plata
# Processing Record 27 of Set 19 | saravena
# Processing Record 28 of Set 19 | touros
# Processing Record 29 of Set 19 | hithadhoo
# Processing Record 30 of Set 19 | upernavik
# Processing Record 31 of Set 19 | visby
# Processing Record 32 of Set 19 | shubarshi
# Processing Record 33 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 19 | port moresby
# Processing Record 35 of Set 19 | pangai
# Processing Record 36 of Set 19 | channel-port aux basques
# Processing Record 37 of Set 19 | lokoja
# Processing Record 38 of Set 19 | hanover
# Processing Record 39 of Set 19 | charlestown
# Processing Record 40 of Set 19 | margate
# Processing Record 41 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 19 | ambilobe
# Processing Record 43 of Set 19 | kavieng
# Processing Record 44 of Set 19 | savannah bight
# Processing Record 45 of Set 19 | male
# Processing Record 46 of Set 19 | pisco
# Processing Record 47 of Set 19 | manzil salim
# Processing Record 48 of Set 19 | bethel
# Processing Record 49 of Set 19 | ancud
# Processing Record 50 of Set 19 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 20 | carroll
# Processing Record 2 of Set 20 | kilindoni
# Processing Record 3 of Set 20 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 20 | durango
# Processing Record 5 of Set 20 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 20 | dera bugti
# Processing Record 7 of Set 20 | cidreira
# Processing Record 8 of Set 20 | macau
# Processing Record 9 of Set 20 | ust-kuyga
# Processing Record 10 of Set 20 | semnan
# Processing Record 11 of Set 20 | ixtapa
# Processing Record 12 of Set 20 | kyren
# Processing Record 13 of Set 20 | vitim
# Processing Record 14 of Set 20 | galveston
# Processing Record 15 of Set 20 | galdar
# Processing Record 16 of Set 20 | hambantota
# Processing Record 17 of Set 20 | kerouane
# Processing Record 18 of Set 20 | kaeo
# Processing Record 19 of Set 20 | mian channun
# Processing Record 20 of Set 20 | sao filipe
# Processing Record 21 of Set 20 | panjwin
# City not found. Skipping...
# Processing Record 22 of Set 20 | yeppoon
# Processing Record 23 of Set 20 | leningradskiy
# Processing Record 24 of Set 20 | gizo
# Processing Record 25 of Set 20 | lebu
# Processing Record 26 of Set 20 | areosa
# Processing Record 27 of Set 20 | zlitan
# Processing Record 28 of Set 20 | muros
# Processing Record 29 of Set 20 | pevek
# Processing Record 30 of Set 20 | aswan
# Processing Record 31 of Set 20 | teguise
# Processing Record 32 of Set 20 | manta
# Processing Record 33 of Set 20 | evensk
# Processing Record 34 of Set 20 | stromness
# Processing Record 35 of Set 20 | high level
# Processing Record 36 of Set 20 | atar
# Processing Record 37 of Set 20 | saldanha
# Processing Record 38 of Set 20 | bubaque
# Processing Record 39 of Set 20 | bull savanna
# Processing Record 40 of Set 20 | te anau
# Processing Record 41 of Set 20 | mehamn
# Processing Record 42 of Set 20 | waingapu
# Processing Record 43 of Set 20 | forio
# Processing Record 44 of Set 20 | bonnyville
# Processing Record 45 of Set 20 | upata
# Processing Record 46 of Set 20 | cabo san lucas
# Processing Record 47 of Set 20 | broken hill
# Processing Record 48 of Set 20 | palmer
# Processing Record 49 of Set 20 | minsk
# Processing Record 50 of Set 20 | cherskiy
# Processing Record 1 of Set 21 | san rafael
# Processing Record 2 of Set 21 | ilulissat
# Processing Record 3 of Set 21 | iquitos
# Processing Record 4 of Set 21 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 21 | tateyama
# Processing Record 6 of Set 21 | vigrestad
# Processing Record 7 of Set 21 | jacareacanga
# Processing Record 8 of Set 21 | coihaique
# Processing Record 9 of Set 21 | dukat
# Processing Record 10 of Set 21 | ginda
# Processing Record 11 of Set 21 | hokitika
# Processing Record 12 of Set 21 | buenos aires
# Processing Record 13 of Set 21 | sharkan
# Processing Record 14 of Set 21 | nishihara
# Processing Record 15 of Set 21 | meulaboh
# Processing Record 16 of Set 21 | port shepstone
# Processing Record 17 of Set 21 | cap malheureux
# Processing Record 18 of Set 21 | awbari
# Processing Record 19 of Set 21 | bambanglipuro
# Processing Record 20 of Set 21 | serik
# Processing Record 21 of Set 21 | sabha
# Processing Record 22 of Set 21 | norman wells
# Processing Record 23 of Set 21 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 21 | jiuquan
# Processing Record 25 of Set 21 | geraldton
# Processing Record 26 of Set 21 | north bend
# Processing Record 27 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 21 | half moon bay
# Processing Record 29 of Set 21 | salvador
# Processing Record 30 of Set 21 | korla
# Processing Record 31 of Set 21 | klaksvik
# Processing Record 32 of Set 21 | mahebourg
# Processing Record 33 of Set 21 | beira
# Processing Record 34 of Set 21 | belaya gora
# Processing Record 35 of Set 21 | pringsewu
# Processing Record 36 of Set 21 | coruripe
# Processing Record 37 of Set 21 | moratuwa
# Processing Record 38 of Set 21 | santa fe
# Processing Record 39 of Set 21 | east london
# Processing Record 40 of Set 21 | maniitsoq
# Processing Record 41 of Set 21 | marystown
# Processing Record 42 of Set 21 | hibbing
# Processing Record 43 of Set 21 | puerto gaitan
# Processing Record 44 of Set 21 | lengshuijiang
# Processing Record 45 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 21 | myslenice
# Processing Record 47 of Set 21 | rio grande
# Processing Record 48 of Set 21 | carnarvon
# Processing Record 49 of Set 21 | north platte
# Processing Record 50 of Set 21 | hasaki
# Processing Record 1 of Set 22 | saint-joseph
# Processing Record 2 of Set 22 | kigoma
# Processing Record 3 of Set 22 | tari
# Processing Record 4 of Set 22 | kaitangata
# Processing Record 5 of Set 22 | rock sound
# Processing Record 6 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 22 | springbok
# Processing Record 8 of Set 22 | hegang
# Processing Record 9 of Set 22 | san rafael del sur
# Processing Record 10 of Set 22 | couva
# Processing Record 11 of Set 22 | tutoia
# Processing Record 12 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 22 | grafenhainichen
# Processing Record 14 of Set 22 | luderitz
# Processing Record 15 of Set 22 | birin
# Processing Record 16 of Set 22 | rawson
# Processing Record 17 of Set 22 | rosetta
# Processing Record 18 of Set 22 | tungor
# Processing Record 19 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 22 | illela
# Processing Record 22 of Set 22 | tabas
# Processing Record 23 of Set 22 | prescott
# Processing Record 24 of Set 22 | padang
# Processing Record 25 of Set 22 | pangody
# Processing Record 26 of Set 22 | torbay
# Processing Record 27 of Set 22 | empangeni
# Processing Record 28 of Set 22 | burgeo
# Processing Record 29 of Set 22 | sassandra
# Processing Record 30 of Set 22 | dingle
# Processing Record 31 of Set 22 | colares
# Processing Record 32 of Set 22 | lere
# Processing Record 33 of Set 22 | tecoanapa
# Processing Record 34 of Set 22 | mayo
# Processing Record 35 of Set 22 | inuvik
# Processing Record 36 of Set 22 | zhenjiang
# Processing Record 37 of Set 22 | vila velha
# Processing Record 38 of Set 22 | manggar
# Processing Record 39 of Set 22 | pilar
# Processing Record 40 of Set 22 | aporawan
# City not found. Skipping...
# Processing Record 41 of Set 22 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 22 | humberto de campos
# Processing Record 43 of Set 22 | ribeira brava
# Processing Record 44 of Set 22 | springfield
# Processing Record 45 of Set 22 | comodoro rivadavia
# Processing Record 46 of Set 22 | kirakira
# Processing Record 47 of Set 22 | nikel
# Processing Record 48 of Set 22 | estelle
# Processing Record 49 of Set 22 | bathsheba
# Processing Record 50 of Set 22 | verkhoyansk
# Processing Record 1 of Set 23 | chegdomyn
# Processing Record 2 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 23 | qena
# Processing Record 4 of Set 23 | gabu
# Processing Record 5 of Set 23 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 23 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 23 | kokomo
# Processing Record 8 of Set 23 | boyolangu
# Processing Record 9 of Set 23 | umm jarr
# City not found. Skipping...
# Processing Record 10 of Set 23 | baker city
# Processing Record 11 of Set 23 | parfenyevo
# Processing Record 12 of Set 23 | anadyr
# Processing Record 13 of Set 23 | gibsons
# Processing Record 14 of Set 23 | virden
# Processing Record 15 of Set 23 | talcahuano
# Processing Record 16 of Set 23 | murgab
# Processing Record 17 of Set 23 | port blair
# Processing Record 18 of Set 23 | saint-philippe
# Processing Record 19 of Set 23 | valparaiso
# Processing Record 20 of Set 23 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 23 | novotalitsy
# City not found. Skipping...
# Processing Record 22 of Set 23 | durban
# Processing Record 23 of Set 23 | khuzhir
# Processing Record 24 of Set 23 | falun
# Processing Record 25 of Set 23 | alta gracia
# Processing Record 26 of Set 23 | fort nelson
# Processing Record 27 of Set 23 | poso
# Processing Record 28 of Set 23 | itororo
# Processing Record 29 of Set 23 | trstena
# Processing Record 30 of Set 23 | mirina
# City not found. Skipping...
# Processing Record 31 of Set 23 | iwanai
# Processing Record 32 of Set 23 | nioro
# Processing Record 33 of Set 23 | hami
# Processing Record 34 of Set 23 | vardo
# Processing Record 35 of Set 23 | tevriz
# Processing Record 36 of Set 23 | guane
# Processing Record 37 of Set 23 | marawi
# Processing Record 38 of Set 23 | dibaya
# City not found. Skipping...
# Processing Record 39 of Set 23 | takoradi
# Processing Record 40 of Set 23 | grajau
# Processing Record 41 of Set 23 | dali
# Processing Record 42 of Set 23 | tchaourou
# Processing Record 43 of Set 23 | codrington
# Processing Record 44 of Set 23 | kudahuvadhoo
# Processing Record 45 of Set 23 | saint-pierre
# Processing Record 46 of Set 23 | deputatskiy
# Processing Record 47 of Set 23 | asau
# Processing Record 48 of Set 23 | kijang
# Processing Record 49 of Set 23 | ijui
# Processing Record 50 of Set 23 | huayucachi
# Processing Record 1 of Set 24 | pershotravneve
# Processing Record 2 of Set 24 | marsh harbour
# Processing Record 3 of Set 24 | myaundzha
# Processing Record 4 of Set 24 | catcau
# City not found. Skipping...
# Processing Record 5 of Set 24 | alyangula
# Processing Record 6 of Set 24 | wau
# Processing Record 7 of Set 24 | serebryansk
# Processing Record 8 of Set 24 | luan
# Processing Record 9 of Set 24 | nizwa
# Processing Record 10 of Set 24 | grand gaube
# Processing Record 11 of Set 24 | elizabeth city
# Processing Record 12 of Set 24 | ostersund
# Processing Record 13 of Set 24 | joshimath
# Processing Record 14 of Set 24 | linxia
# Processing Record 15 of Set 24 | vagur
# Processing Record 16 of Set 24 | saint anthony
# Processing Record 17 of Set 24 | dujuma
# City not found. Skipping...
# Processing Record 18 of Set 24 | kastornoye
# Processing Record 19 of Set 24 | vila franca do campo
# Processing Record 20 of Set 24 | balikpapan
# Processing Record 21 of Set 24 | colesberg
# Processing Record 22 of Set 24 | mareeba
# Processing Record 23 of Set 24 | lavrentiya
# Processing Record 24 of Set 24 | tocopilla
# Processing Record 25 of Set 24 | lata
# Processing Record 26 of Set 24 | sambava
# Processing Record 27 of Set 24 | flinders
# Processing Record 28 of Set 24 | sorland
# Processing Record 29 of Set 24 | chute-aux-outardes
# Processing Record 30 of Set 24 | karlstad
# Processing Record 31 of Set 24 | vikhorevka
# Processing Record 32 of Set 24 | honiara
# Processing Record 33 of Set 24 | boundiali
# Processing Record 34 of Set 24 | garissa
# Processing Record 35 of Set 24 | krasnyy chikoy
# Processing Record 36 of Set 24 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 24 | santa cruz
# Processing Record 38 of Set 24 | nyurba
# Processing Record 39 of Set 24 | buraydah
# Processing Record 40 of Set 24 | naryan-mar
# Processing Record 41 of Set 24 | vasilsursk
# Processing Record 42 of Set 24 | ossora
# Processing Record 43 of Set 24 | nogliki
# Processing Record 44 of Set 24 | adrar
# Processing Record 45 of Set 24 | marsa matruh
# Processing Record 46 of Set 24 | dickinson
# Processing Record 47 of Set 24 | san andres
# Processing Record 48 of Set 24 | ust-omchug
# Processing Record 49 of Set 24 | wuwei
# Processing Record 50 of Set 24 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 25 | namatanai
# Processing Record 2 of Set 25 | walvis bay
# Processing Record 3 of Set 25 | lorengau
# Processing Record 4 of Set 25 | souillac
# Processing Record 5 of Set 25 | ayan
# Processing Record 6 of Set 25 | viedma
# Processing Record 7 of Set 25 | boende
# Processing Record 8 of Set 25 | yaan
# Processing Record 9 of Set 25 | horasan
# Processing Record 10 of Set 25 | haines junction
# Processing Record 11 of Set 25 | tiarei
# Processing Record 12 of Set 25 | vao
# Processing Record 13 of Set 25 | olafsvik
# Processing Record 14 of Set 25 | homer
# Processing Record 15 of Set 25 | mount gambier
# Processing Record 16 of Set 25 | ahuimanu
# Processing Record 17 of Set 25 | khani
# Processing Record 18 of Set 25 | san pedro de macoris
# Processing Record 19 of Set 25 | valera
# Processing Record 20 of Set 25 | el higo
# Processing Record 21 of Set 25 | sao joao da barra
# Processing Record 22 of Set 25 | umm kaddadah
# Processing Record 23 of Set 25 | brookhaven
# Processing Record 24 of Set 25 | jiayuguan
# Processing Record 25 of Set 25 | ojinaga
# Processing Record 26 of Set 25 | jumla
# Processing Record 27 of Set 25 | port hedland
# Processing Record 28 of Set 25 | nambiyur
# Processing Record 29 of Set 25 | sharan
# Processing Record 30 of Set 25 | bolshaya rechka
# Processing Record 31 of Set 25 | harper
# Processing Record 32 of Set 25 | andenes
# Processing Record 33 of Set 25 | ampanihy
# Processing Record 34 of Set 25 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 25 | frankfort
# Processing Record 36 of Set 25 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 25 | tucurui
# Processing Record 38 of Set 25 | turukhansk
# Processing Record 39 of Set 25 | belmonte
# Processing Record 40 of Set 25 | nouadhibou
# Processing Record 41 of Set 25 | hay river
# Processing Record 42 of Set 25 | stornoway
# Processing Record 43 of Set 25 | tekanto
# Processing Record 44 of Set 25 | northam
# Processing Record 45 of Set 25 | mogadishu
# Processing Record 46 of Set 25 | canjulao
# Processing Record 47 of Set 25 | effium
# Processing Record 48 of Set 25 | nushki
# Processing Record 49 of Set 25 | khovu-aksy
# Processing Record 50 of Set 25 | kamenka
# Processing Record 1 of Set 26 | crossville
# Processing Record 2 of Set 26 | loreto
# Processing Record 3 of Set 26 | uetze
# Processing Record 4 of Set 26 | acapulco
# Processing Record 5 of Set 26 | abha
# Processing Record 6 of Set 26 | sobolevo
# Processing Record 7 of Set 26 | altus
# Processing Record 8 of Set 26 | tuatapere
# Processing Record 9 of Set 26 | hervey bay
# Processing Record 10 of Set 26 | erzin
# Processing Record 11 of Set 26 | morant bay
# Processing Record 12 of Set 26 | tepechitlan
# Processing Record 13 of Set 26 | ondangwa
# Processing Record 14 of Set 26 | naze
# Processing Record 15 of Set 26 | oliver
# Processing Record 16 of Set 26 | carballo
# Processing Record 17 of Set 26 | kenora
# Processing Record 18 of Set 26 | odweyne
# Processing Record 19 of Set 26 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 26 | bozuyuk
# Processing Record 21 of Set 26 | ponneri
# Processing Record 22 of Set 26 | noumea
# Processing Record 23 of Set 26 | maltahohe
# Processing Record 24 of Set 26 | necochea
# Processing Record 25 of Set 26 | lazaro cardenas
# Processing Record 26 of Set 26 | tambopata
# Processing Record 27 of Set 26 | stonehaven
# Processing Record 28 of Set 26 | zabaykalsk
# Processing Record 29 of Set 26 | nome
# Processing Record 30 of Set 26 | talnakh
# Processing Record 31 of Set 26 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 26 | banda aceh
# Processing Record 33 of Set 26 | khandyga
# Processing Record 34 of Set 26 | kodinsk
# Processing Record 35 of Set 26 | port lincoln
# Processing Record 36 of Set 26 | quelimane
# Processing Record 37 of Set 26 | khislavichi
# Processing Record 38 of Set 26 | burica
# City not found. Skipping...
# Processing Record 39 of Set 26 | tsumeb
# Processing Record 40 of Set 26 | bosaso
# Processing Record 41 of Set 26 | skelleftea
# Processing Record 42 of Set 26 | ocean city
# Processing Record 43 of Set 26 | manicore
# Processing Record 44 of Set 26 | san patricio
# Processing Record 45 of Set 26 | kem
# Processing Record 46 of Set 26 | port-gentil
# Processing Record 47 of Set 26 | swan hill
# Processing Record 48 of Set 26 | saint-louis
# Processing Record 49 of Set 26 | amazar
# Processing Record 50 of Set 26 | svetlogorsk
# Processing Record 1 of Set 27 | tautira
# Processing Record 2 of Set 27 | pareora
# Processing Record 3 of Set 27 | umea
# Processing Record 4 of Set 27 | khandbari
# Processing Record 5 of Set 27 | kosa
# Processing Record 6 of Set 27 | roald
# Processing Record 7 of Set 27 | songea
# Processing Record 8 of Set 27 | tandil
# Processing Record 9 of Set 27 | dori
# Processing Record 10 of Set 27 | tazmalt
# Processing Record 11 of Set 27 | boa vista
# Processing Record 12 of Set 27 | itarema
# Processing Record 13 of Set 27 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 27 | rapid city
# Processing Record 15 of Set 27 | champerico
# Processing Record 16 of Set 27 | lufilufi
# Processing Record 17 of Set 27 | gazli
# Processing Record 18 of Set 27 | felidhoo
# City not found. Skipping...
# Processing Record 19 of Set 27 | lima
# Processing Record 20 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 27 | plover
# Processing Record 22 of Set 27 | rantoul
# Processing Record 23 of Set 27 | sibolga
# Processing Record 24 of Set 27 | gbarnga
# Processing Record 25 of Set 27 | jacmel
# Processing Record 26 of Set 27 | lagos
# Processing Record 27 of Set 27 | jiexiu
# Processing Record 28 of Set 27 | tashtyp
# Processing Record 29 of Set 27 | port-cartier
# Processing Record 30 of Set 27 | kariba
# Processing Record 31 of Set 27 | bandarbeyla
# Processing Record 32 of Set 27 | keshod
# Processing Record 33 of Set 27 | susurluk
# Processing Record 34 of Set 27 | hovd
# Processing Record 35 of Set 27 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 27 | amahai
# Processing Record 37 of Set 27 | ondjiva
# Processing Record 38 of Set 27 | mutoko
# Processing Record 39 of Set 27 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 27 | camacha
# Processing Record 41 of Set 27 | adre
# Processing Record 42 of Set 27 | qui nhon
# Processing Record 43 of Set 27 | sao jose da coroa grande
# Processing Record 44 of Set 27 | saint-augustin
# Processing Record 45 of Set 27 | longyan
# Processing Record 46 of Set 27 | praia da vitoria
# Processing Record 47 of Set 27 | kalmunai
# Processing Record 48 of Set 27 | akdepe
# Processing Record 49 of Set 27 | birobidzhan
# Processing Record 50 of Set 27 | vadso
# Processing Record 1 of Set 28 | luganville
# Processing Record 2 of Set 28 | sitka
# Processing Record 3 of Set 28 | bafra
# Processing Record 4 of Set 28 | chebarkul
# Processing Record 5 of Set 28 | lasa
# Processing Record 6 of Set 28 | awjilah
# Processing Record 7 of Set 28 | asyut
# Processing Record 8 of Set 28 | taoudenni
# Processing Record 9 of Set 28 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 28 | bardiyah
# Processing Record 11 of Set 28 | pudozh
# Processing Record 12 of Set 28 | sapa
# Processing Record 13 of Set 28 | makaryev
# Processing Record 14 of Set 28 | corinto
# Processing Record 15 of Set 28 | bengkalis
# City not found. Skipping...
# Processing Record 16 of Set 28 | lemesos
# City not found. Skipping...
# Processing Record 17 of Set 28 | gigmoto
# Processing Record 18 of Set 28 | paragominas
# Processing Record 19 of Set 28 | yerbogachen
# Processing Record 20 of Set 28 | kikwit
# Processing Record 21 of Set 28 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 28 | florida
# Processing Record 23 of Set 28 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 28 | zhangjiakou
# Processing Record 25 of Set 28 | kropotkin
# Processing Record 26 of Set 28 | udachnyy
# Processing Record 27 of Set 28 | olaine
# Processing Record 28 of Set 28 | huilong
# Processing Record 29 of Set 28 | biak
# Processing Record 30 of Set 28 | yangambi
# Processing Record 31 of Set 28 | srednekolymsk
# Processing Record 32 of Set 28 | rolleston
# Processing Record 33 of Set 28 | swift current
# Processing Record 34 of Set 28 | socorro
# Processing Record 35 of Set 28 | alunis
# Processing Record 36 of Set 28 | kyzyl-mazhalyk
# Processing Record 37 of Set 28 | cayenne
# Processing Record 38 of Set 28 | torres
# Processing Record 39 of Set 28 | katsuura
# Processing Record 40 of Set 28 | seoul
# Processing Record 41 of Set 28 | zonguldak
# Processing Record 42 of Set 28 | tres lagoas
# Processing Record 43 of Set 28 | henties bay
# Processing Record 44 of Set 28 | katangli
# Processing Record 45 of Set 28 | nava
# Processing Record 46 of Set 28 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 28 | asheville
# Processing Record 48 of Set 28 | osmena
# Processing Record 49 of Set 28 | lompoc
# Processing Record 50 of Set 28 | kemijarvi
# Processing Record 1 of Set 29 | linguere
# Processing Record 2 of Set 29 | trairi
# Processing Record 3 of Set 29 | owando
# Processing Record 4 of Set 29 | lukovit
# Processing Record 5 of Set 29 | ouallam
# Processing Record 6 of Set 29 | westport
# Processing Record 7 of Set 29 | saint-francois
# Processing Record 8 of Set 29 | erenhot
# Processing Record 9 of Set 29 | dolores
# Processing Record 10 of Set 29 | kjollefjord
# Processing Record 11 of Set 29 | san policarpo
# Processing Record 12 of Set 29 | calvinia
# Processing Record 13 of Set 29 | san carlos de bariloche
# Processing Record 14 of Set 29 | bella union
# Processing Record 15 of Set 29 | mixtepec
# City not found. Skipping...
# Processing Record 16 of Set 29 | dolgoye
# Processing Record 17 of Set 29 | sinnamary
# Processing Record 18 of Set 29 | paamiut
# Processing Record 19 of Set 29 | lerwick
# Processing Record 20 of Set 29 | marietta
# Processing Record 21 of Set 29 | buala
# Processing Record 22 of Set 29 | berea
# Processing Record 23 of Set 29 | thunder bay
# Processing Record 24 of Set 29 | verin
# Processing Record 25 of Set 29 | ubrique
# Processing Record 26 of Set 29 | usogorsk
# Processing Record 27 of Set 29 | muyezerskiy
# Processing Record 28 of Set 29 | matale
# Processing Record 29 of Set 29 | samandag
# Processing Record 30 of Set 29 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 29 | gari
# Processing Record 32 of Set 29 | mill valley
# Processing Record 33 of Set 29 | bulgan
# Processing Record 34 of Set 29 | zhezkazgan
# Processing Record 35 of Set 29 | alta floresta
# Processing Record 36 of Set 29 | szprotawa
# Processing Record 37 of Set 29 | churapcha
# Processing Record 38 of Set 29 | zhangye
# Processing Record 39 of Set 29 | asfi
# Processing Record 40 of Set 29 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 29 | natalio
# Processing Record 42 of Set 29 | algiers
# Processing Record 43 of Set 29 | shirokiy
# Processing Record 44 of Set 29 | volkhov
# Processing Record 45 of Set 29 | ratnagiri
# Processing Record 46 of Set 29 | fortuna
# Processing Record 47 of Set 29 | muravlenko
# Processing Record 48 of Set 29 | aras
# Processing Record 49 of Set 29 | hauterive
# Processing Record 50 of Set 29 | forbes
# Processing Record 1 of Set 30 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 30 | hornepayne
# Processing Record 3 of Set 30 | lanzhou
# Processing Record 4 of Set 30 | abancay
# Processing Record 5 of Set 30 | negara
# Processing Record 6 of Set 30 | novikovo
# Processing Record 7 of Set 30 | burnie
# Processing Record 8 of Set 30 | binabalian
# Processing Record 9 of Set 30 | linares
# Processing Record 10 of Set 30 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 30 | ulladulla
# Processing Record 12 of Set 30 | mineros
# Processing Record 13 of Set 30 | santa ines
# Processing Record 14 of Set 30 | salina cruz
# Processing Record 15 of Set 30 | skjervoy
# Processing Record 16 of Set 30 | san fernando
# Processing Record 17 of Set 30 | laguna
# Processing Record 18 of Set 30 | sandwick
# Processing Record 19 of Set 30 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 30 | alirajpur
# Processing Record 21 of Set 30 | ozu
# Processing Record 22 of Set 30 | tezu
# Processing Record 23 of Set 30 | peniche
# Processing Record 24 of Set 30 | cobija
# Processing Record 25 of Set 30 | mikkeli
# Processing Record 26 of Set 30 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 30 | prince albert
# Processing Record 28 of Set 30 | petatlan
# Processing Record 29 of Set 30 | bontang
# Processing Record 30 of Set 30 | bilma
# Processing Record 31 of Set 30 | bonthe
# Processing Record 32 of Set 30 | bonaventure
# Processing Record 33 of Set 30 | katobu
# Processing Record 34 of Set 30 | plettenberg bay
# Processing Record 35 of Set 30 | valley city
# Processing Record 36 of Set 30 | namibe
# Processing Record 37 of Set 30 | sao luis de montes belos
# Processing Record 38 of Set 30 | caravelas
# Processing Record 39 of Set 30 | kununurra
# Processing Record 40 of Set 30 | warrnambool
# Processing Record 41 of Set 30 | marang
# Processing Record 42 of Set 30 | baraboo
# Processing Record 43 of Set 30 | nokaneng
# Processing Record 44 of Set 30 | sursk
# Processing Record 45 of Set 30 | boma
# Processing Record 46 of Set 30 | hofn
# Processing Record 47 of Set 30 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 30 | fengrun
# Processing Record 49 of Set 30 | ikryanoye
# Processing Record 50 of Set 30 | laurel
# Processing Record 1 of Set 31 | kribi
# Processing Record 2 of Set 31 | mocuba
# Processing Record 3 of Set 31 | dargaville
# Processing Record 4 of Set 31 | morondava
# Processing Record 5 of Set 31 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Kahului      US  20.8947 -156.4700     82.42        66
# 1            Angoram      PG  -4.0625  144.0661     77.29        95
# 2              Ukiah      US  39.1502 -123.2078     70.16        39
# 3  San Mateo Ixtatan      GT  15.8319  -91.4781     67.73        31
# 4            Longkou      CN  37.6508  120.3286     52.39        59
# 5         Bredasdorp      ZA -34.5322   20.0403     60.13        93
# 6         Port Hardy      CA  50.6996 -127.4199     48.76        59
# 7             Yulara      AU -25.2406  130.9889     60.64        51
# 8        Port Alfred      ZA -33.5906   26.8910     63.97        82
# 9              Vaini      TO -21.2000 -175.2000     81.23        80
#
#    Cloudiness  Wind Speed Current Description
# 0          40       16.11    scattered clouds
# 1          69        1.41          light rain
# 2           0        9.22           clear sky
# 3          17        6.04          few clouds
# 4         100        6.44     overcast clouds
# 5          75        4.41       broken clouds
# 6          75       19.64       broken clouds
# 7           1        8.05           clear sky
# 8          20        9.86          few clouds
# 9         100       13.80     overcast clouds

# %%
# Export the DataFrame as a CSV file
city_data_df.to_csv("WeatherPy_Database.csv")
